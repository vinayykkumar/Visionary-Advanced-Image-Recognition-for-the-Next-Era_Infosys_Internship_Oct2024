# %%
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def preprocess_and_augment(input_dir, output_dir, img_size=(128, 128), augmentations=5):
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Data augmentation generator
    datagen = ImageDataGenerator(
        rotation_range=30,        # Rotate images by up to 30 degrees
        width_shift_range=0.1,    # Shift width by 10%
        height_shift_range=0.1,   # Shift height by 10%
        zoom_range=0.2,           # Zoom in and out by 20%
        horizontal_flip=True,     # Flip images horizontally
        fill_mode='nearest'       # Fill missing pixels using nearest neighbors
    )

    # Iterate through each person's folder in the dataset
    for person_name in os.listdir(input_dir):
        person_folder = os.path.join(input_dir, person_name)
        output_person_folder = os.path.join(output_dir, person_name)

        if not os.path.isdir(person_folder):
            continue  # Skip files, only process directories

        # Create corresponding output directory for each person if it doesn't exist
        if not os.path.exists(output_person_folder):
            os.makedirs(output_person_folder)

        # Process each image in the person's folder
        for img_name in os.listdir(person_folder):
            img_path = os.path.join(person_folder, img_name)
            
            # Read the image
            image = cv2.imread(img_path)
            if image is None:
                print(f"Warning: Could not read image {img_path}")
                continue

            # Step 1: Resize the image
            image_resized = cv2.resize(image, img_size)

            # Step 2: Apply Bilateral Filter for noise reduction while preserving edges
            image_bilateral = cv2.bilateralFilter(image_resized, d=9, sigmaColor=75, sigmaSpace=75)

            # Step 3: Convert to grayscale for thresholding
            gray = cv2.cvtColor(image_bilateral, cv2.COLOR_BGR2GRAY)

            # Step 4: Apply simple thresholding for background removal
            _, thresholded = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY_INV)

            # Apply the threshold mask to the original image
            foreground = cv2.bitwise_and(image_bilateral, image_bilateral, mask=thresholded)

            # Save the preprocessed image
            preprocessed_path = os.path.join(output_person_folder, f"processed_{img_name}")
            cv2.imwrite(preprocessed_path, foreground)
            print(f"Preprocessed and saved: {preprocessed_path}")

            # Step 5: Apply data augmentation
            # Reshape to (1, height, width, channels) for the augmentation generator
            foreground = np.expand_dims(foreground, axis=0)

            # Generate and save augmented images
            aug_iter = datagen.flow(foreground, batch_size=1)
            for i in range(augmentations):
                augmented_image = next(aug_iter)[0].astype(np.uint8)  # Extract augmented image
                aug_img_path = os.path.join(output_person_folder, f"aug_{i}_{img_name}")
                cv2.imwrite(aug_img_path, augmented_image)
                print(f"Augmented and saved: {aug_img_path}")

# Define input and output directories and call the function
input_directory = "Indian_actors_faces"          # Replace with the path to your dataset folder
output_directory = "augmented_dataset"  # Where augmented images will be saved
preprocess_and_augment(input_directory, output_directory, augmentations=2)
# Out:
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_090288c011.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_090288c011.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_090288c011.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_0b6f381312.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_0b6f381312.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_0b6f381312.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_12fa72e5b3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_12fa72e5b3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_12fa72e5b3.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_1ab9ede00c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_1ab9ede00c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_1ab9ede00c.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_1c74bd375f.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_1c74bd375f.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_1c74bd375f.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_1e696e3b2c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_1e696e3b2c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_1e696e3b2c.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_229eef1a94.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_229eef1a94.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_229eef1a94.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_35468bd6f3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_35468bd6f3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_35468bd6f3.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_36e69eecad.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_36e69eecad.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_36e69eecad.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_378b296190.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_378b296190.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_378b296190.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_3afd33c246.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_3afd33c246.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_3afd33c246.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_3b35ba2a71.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_3b35ba2a71.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_3b35ba2a71.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_4415726852.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_4415726852.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_4415726852.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_466f45085e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_466f45085e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_466f45085e.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_47e50a07e7.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_47e50a07e7.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_47e50a07e7.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_4c8ccae220.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_4c8ccae220.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_4c8ccae220.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_4d16c07b22.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_4d16c07b22.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_4d16c07b22.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_5373ce61ba.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_5373ce61ba.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_5373ce61ba.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_53d5937f45.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_53d5937f45.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_53d5937f45.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_59bd5065c4.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_59bd5065c4.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_59bd5065c4.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_5b1cbd274f.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_5b1cbd274f.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_5b1cbd274f.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_61f4a63747.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_61f4a63747.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_61f4a63747.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_65f922a5db.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_65f922a5db.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_65f922a5db.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_6618c500ff.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_6618c500ff.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_6618c500ff.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_66304fa693.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_66304fa693.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_66304fa693.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_6b6f95effe.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_6b6f95effe.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_6b6f95effe.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_6c318c2ccf.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_6c318c2ccf.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_6c318c2ccf.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_70b0eb7ef5.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_70b0eb7ef5.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_70b0eb7ef5.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_7329a3d476.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_7329a3d476.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_7329a3d476.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_7f7038975a.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_7f7038975a.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_7f7038975a.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_822e497bd6.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_822e497bd6.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_822e497bd6.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_8b22aa69a5.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_8b22aa69a5.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_8b22aa69a5.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_8dc9380ba1.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_8dc9380ba1.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_8dc9380ba1.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_933f948f7e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_933f948f7e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_933f948f7e.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_961ac21a24.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_961ac21a24.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_961ac21a24.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_9eed628c14.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_9eed628c14.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_9eed628c14.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_a51311f18e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_a51311f18e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_a51311f18e.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_accb121b06.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_accb121b06.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_accb121b06.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_adcf163f9c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_adcf163f9c.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_adcf163f9c.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_b17d846d2e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_b17d846d2e.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_b17d846d2e.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_b4c8fc6ee3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_b4c8fc6ee3.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_b4c8fc6ee3.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_b9ea51f1cb.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_b9ea51f1cb.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_b9ea51f1cb.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_bc10995793.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_bc10995793.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_bc10995793.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_bccd3ed0f8.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_bccd3ed0f8.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_bccd3ed0f8.jpg
# Preprocessed and saved: augmented_dataset\pankaj_kapur\processed_bf253e9a88.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_0_bf253e9a88.jpg
# Augmented and saved: augmented_dataset\pankaj_kapur\aug_1_bf253e9a88.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_0ac356b1d9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_0ac356b1d9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_0ac356b1d9.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_0ad408cf42.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_0ad408cf42.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_0ad408cf42.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_0adda37db4.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_0adda37db4.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_0adda37db4.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_0fc20fcf65.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_0fc20fcf65.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_0fc20fcf65.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_14e1383527.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_14e1383527.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_14e1383527.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_181c9679af.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_181c9679af.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_181c9679af.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_19f6f5dce3.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_19f6f5dce3.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_19f6f5dce3.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_1eb0598dc8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_1eb0598dc8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_1eb0598dc8.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_1fd8aebb12.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_1fd8aebb12.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_1fd8aebb12.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_21ef2f4124.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_21ef2f4124.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_21ef2f4124.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_233f3e9766.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_233f3e9766.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_233f3e9766.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_270e67eff5.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_270e67eff5.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_270e67eff5.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_28a5a98c6f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_28a5a98c6f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_28a5a98c6f.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_299c3d8831.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_299c3d8831.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_299c3d8831.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_2b6f679267.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_2b6f679267.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_2b6f679267.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_2c01a34eb9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_2c01a34eb9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_2c01a34eb9.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_2c73bb0481.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_2c73bb0481.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_2c73bb0481.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_2f7faee505.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_2f7faee505.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_2f7faee505.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_339c10b3c9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_339c10b3c9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_339c10b3c9.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_367eb32a3a.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_367eb32a3a.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_367eb32a3a.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_36d6ed1aa6.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_36d6ed1aa6.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_36d6ed1aa6.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_372a154590.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_372a154590.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_372a154590.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_372ec67df8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_372ec67df8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_372ec67df8.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_381ce98de9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_381ce98de9.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_381ce98de9.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_3b5ba1d05b.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_3b5ba1d05b.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_3b5ba1d05b.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_41b77df3cb.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_41b77df3cb.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_41b77df3cb.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_4e4ef45858.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_4e4ef45858.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_4e4ef45858.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_4f5ee44d28.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_4f5ee44d28.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_4f5ee44d28.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_587cbb4834.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_587cbb4834.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_587cbb4834.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_5d5d4354b8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_5d5d4354b8.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_5d5d4354b8.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_5f606d8219.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_5f606d8219.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_5f606d8219.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_65aa3a010d.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_65aa3a010d.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_65aa3a010d.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_66ca137cd2.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_66ca137cd2.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_66ca137cd2.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_6b4a16155b.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_6b4a16155b.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_6b4a16155b.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_707ef6df3a.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_707ef6df3a.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_707ef6df3a.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_73f11e638f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_73f11e638f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_73f11e638f.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_7a075d4375.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_7a075d4375.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_7a075d4375.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_7b2f2e1c90.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_7b2f2e1c90.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_7b2f2e1c90.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_7c206d53d3.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_7c206d53d3.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_7c206d53d3.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_8a80ce056f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_8a80ce056f.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_8a80ce056f.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_8b101e203c.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_8b101e203c.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_8b101e203c.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_8efbbd2294.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_8efbbd2294.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_8efbbd2294.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_8fbf7c1787.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_8fbf7c1787.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_8fbf7c1787.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_98e30ff05d.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_98e30ff05d.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_98e30ff05d.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_9ac5250d87.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_9ac5250d87.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_9ac5250d87.jpg
# Preprocessed and saved: augmented_dataset\pankaj_tripathi\processed_9dc5426b98.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_0_9dc5426b98.jpg
# Augmented and saved: augmented_dataset\pankaj_tripathi\aug_1_9dc5426b98.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_05dba6f1bc.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_05dba6f1bc.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_05dba6f1bc.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_05f6d19903.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_05f6d19903.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_05f6d19903.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_06dbe2c13f.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_06dbe2c13f.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_06dbe2c13f.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_0702f4ce23.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_0702f4ce23.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_0702f4ce23.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_0b520ed85b.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_0b520ed85b.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_0b520ed85b.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_0f70eb8c73.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_0f70eb8c73.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_0f70eb8c73.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_1419c4dfdb.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_1419c4dfdb.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_1419c4dfdb.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_21c02832c8.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_21c02832c8.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_21c02832c8.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_23bee4a033.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_23bee4a033.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_23bee4a033.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_2afbf01950.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_2afbf01950.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_2afbf01950.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_2c59cdd582.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_2c59cdd582.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_2c59cdd582.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_312ed6f329.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_312ed6f329.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_312ed6f329.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_36e581dd9d.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_36e581dd9d.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_36e581dd9d.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3a1958eefa.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3a1958eefa.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3a1958eefa.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3a56ca376a.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3a56ca376a.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3a56ca376a.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3bcdcda6f5.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3bcdcda6f5.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3bcdcda6f5.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3c8a2463a3.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3c8a2463a3.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3c8a2463a3.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3c9ee240c1.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3c9ee240c1.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3c9ee240c1.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3dae14b160.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3dae14b160.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3dae14b160.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_3df5af4955.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_3df5af4955.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_3df5af4955.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_41ca4923d4.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_41ca4923d4.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_41ca4923d4.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_4ac373a460.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_4ac373a460.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_4ac373a460.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_4e9eb45caa.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_4e9eb45caa.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_4e9eb45caa.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_524c07a6bf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_524c07a6bf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_524c07a6bf.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_5dd72c11ba.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_5dd72c11ba.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_5dd72c11ba.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_601f9b3235.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_601f9b3235.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_601f9b3235.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_62e8fa2cbf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_62e8fa2cbf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_62e8fa2cbf.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_65a758163e.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_65a758163e.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_65a758163e.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_6e2f0606d2.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_6e2f0606d2.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_6e2f0606d2.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_711e5a6e43.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_711e5a6e43.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_711e5a6e43.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_74c522ebd1.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_74c522ebd1.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_74c522ebd1.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_76dc99ec3b.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_76dc99ec3b.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_76dc99ec3b.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_7e33aa98cb.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_7e33aa98cb.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_7e33aa98cb.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_7edd362452.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_7edd362452.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_7edd362452.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_805a33c9e7.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_805a33c9e7.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_805a33c9e7.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_80b6bfecaf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_80b6bfecaf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_80b6bfecaf.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_853dce2f80.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_853dce2f80.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_853dce2f80.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_87cb2e22bf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_87cb2e22bf.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_87cb2e22bf.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_8a215ceace.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_8a215ceace.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_8a215ceace.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_8ccfcb4a56.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_8ccfcb4a56.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_8ccfcb4a56.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_923eff26ca.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_923eff26ca.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_923eff26ca.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_96d18c9787.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_96d18c9787.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_96d18c9787.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_97d8225417.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_97d8225417.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_97d8225417.jpg
# Preprocessed and saved: augmented_dataset\paresh_rawal\processed_9c96912a1c.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_0_9c96912a1c.jpg
# Augmented and saved: augmented_dataset\paresh_rawal\aug_1_9c96912a1c.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_00ddf0c0c0.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_00ddf0c0c0.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_00ddf0c0c0.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_00e6c56558.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_00e6c56558.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_00e6c56558.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_031f1ac218.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_031f1ac218.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_031f1ac218.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_0401de24c8.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_0401de24c8.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_0401de24c8.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_0f4530f069.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_0f4530f069.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_0f4530f069.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_10af8ace8f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_10af8ace8f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_10af8ace8f.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_123f7bfd2b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_123f7bfd2b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_123f7bfd2b.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_17bf43eaab.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_17bf43eaab.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_17bf43eaab.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_180bd5de6d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_180bd5de6d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_180bd5de6d.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_18f1f18b03.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_18f1f18b03.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_18f1f18b03.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_1af79beef6.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_1af79beef6.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_1af79beef6.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_1e57a19da5.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_1e57a19da5.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_1e57a19da5.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_22e6626807.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_22e6626807.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_22e6626807.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_2ab5c1145c.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_2ab5c1145c.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_2ab5c1145c.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_2c2920c160.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_2c2920c160.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_2c2920c160.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_2e74e8d74b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_2e74e8d74b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_2e74e8d74b.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_301caab1e4.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_301caab1e4.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_301caab1e4.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_35d20cd98c.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_35d20cd98c.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_35d20cd98c.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_397d3dcfeb.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_397d3dcfeb.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_397d3dcfeb.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_39dcbf4cdd.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_39dcbf4cdd.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_39dcbf4cdd.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_3a0270a928.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_3a0270a928.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_3a0270a928.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_3a444ee3e4.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_3a444ee3e4.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_3a444ee3e4.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_42b244a40f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_42b244a40f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_42b244a40f.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_43ab8add88.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_43ab8add88.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_43ab8add88.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_48d8f2ba3f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_48d8f2ba3f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_48d8f2ba3f.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_4b4113ea19.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_4b4113ea19.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_4b4113ea19.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_4c71f80efb.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_4c71f80efb.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_4c71f80efb.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_4d10af96a0.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_4d10af96a0.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_4d10af96a0.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_516d0bfadf.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_516d0bfadf.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_516d0bfadf.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_54d6b34bda.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_54d6b34bda.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_54d6b34bda.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_58ae6fe7ab.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_58ae6fe7ab.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_58ae6fe7ab.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_5bbba1ac91.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_5bbba1ac91.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_5bbba1ac91.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_647f4ee53e.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_647f4ee53e.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_647f4ee53e.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6a121ea88e.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6a121ea88e.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6a121ea88e.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6b2c2fdd8d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6b2c2fdd8d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6b2c2fdd8d.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6b6ed25a4f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6b6ed25a4f.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6b6ed25a4f.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6d2515487b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6d2515487b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6d2515487b.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6e87555e7a.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6e87555e7a.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6e87555e7a.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_6e8798ee2b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_6e8798ee2b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_6e8798ee2b.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_728eee3a3d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_728eee3a3d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_728eee3a3d.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_781c291310.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_781c291310.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_781c291310.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_826b57c970.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_826b57c970.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_826b57c970.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_844fa384fe.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_844fa384fe.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_844fa384fe.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_8de5168641.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_8de5168641.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_8de5168641.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_94a0cea55b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_94a0cea55b.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_94a0cea55b.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_9c1909fc63.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_9c1909fc63.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_9c1909fc63.jpg
# Preprocessed and saved: augmented_dataset\pawan_malhotra\processed_9c8639dd1d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_0_9c8639dd1d.jpg
# Augmented and saved: augmented_dataset\pawan_malhotra\aug_1_9c8639dd1d.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_007314fcc4.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_007314fcc4.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_007314fcc4.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_076fcdd63c.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_076fcdd63c.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_076fcdd63c.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_084a1f365e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_084a1f365e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_084a1f365e.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_0ba26ac281.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_0ba26ac281.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_0ba26ac281.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_0d94b28e20.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_0d94b28e20.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_0d94b28e20.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_107a7b38db.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_107a7b38db.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_107a7b38db.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_11648d5a26.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_11648d5a26.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_11648d5a26.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_168409b4b2.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_168409b4b2.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_168409b4b2.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_1a2347e044.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_1a2347e044.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_1a2347e044.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_27bf95376c.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_27bf95376c.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_27bf95376c.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_2955542f9b.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_2955542f9b.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_2955542f9b.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_2ea1d5e3cc.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_2ea1d5e3cc.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_2ea1d5e3cc.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_30f721f500.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_30f721f500.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_30f721f500.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_38bf26041e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_38bf26041e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_38bf26041e.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_41e81dbf13.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_41e81dbf13.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_41e81dbf13.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_4318ac717d.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_4318ac717d.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_4318ac717d.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_43b039e731.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_43b039e731.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_43b039e731.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_480f92259f.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_480f92259f.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_480f92259f.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_4ff19ecc6e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_4ff19ecc6e.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_4ff19ecc6e.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_528d282fad.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_528d282fad.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_528d282fad.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_5575501c33.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_5575501c33.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_5575501c33.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_59db4de2f6.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_59db4de2f6.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_59db4de2f6.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_6c611c4729.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_6c611c4729.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_6c611c4729.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_6e42c82037.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_6e42c82037.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_6e42c82037.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_70044c2222.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_70044c2222.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_70044c2222.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_770cc6a298.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_770cc6a298.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_770cc6a298.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_7f6387b938.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_7f6387b938.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_1_7f6387b938.jpg
# Preprocessed and saved: augmented_dataset\pooja_bhatt\processed_804ab99153.jpg
# Augmented and saved: augmented_dataset\pooja_bhatt\aug_0_804ab99153.jpg
# ...
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_3879e4fd32.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_3ecbc01a00.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_3ecbc01a00.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_3ecbc01a00.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_3f99690615.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_3f99690615.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_3f99690615.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_4af4001bc8.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_4af4001bc8.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_4af4001bc8.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_4b9d8420ac.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_4b9d8420ac.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_4b9d8420ac.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_4d5b01522c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_4d5b01522c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_4d5b01522c.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_4dcb7fc04e.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_4dcb7fc04e.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_4dcb7fc04e.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_529f34ba41.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_529f34ba41.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_529f34ba41.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_5746f4c98d.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_5746f4c98d.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_5746f4c98d.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_5d217582ab.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_5d217582ab.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_5d217582ab.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_5e80a9ffc8.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_5e80a9ffc8.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_5e80a9ffc8.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_5ee408b273.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_5ee408b273.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_5ee408b273.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_6152bbef7a.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_6152bbef7a.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_6152bbef7a.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_6503a308a0.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_6503a308a0.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_6503a308a0.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_69aec89eb7.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_69aec89eb7.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_69aec89eb7.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_6c0c924cd1.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_6c0c924cd1.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_6c0c924cd1.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_6db01d9ac6.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_6db01d9ac6.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_6db01d9ac6.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_7cd26f005c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_7cd26f005c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_7cd26f005c.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_7fface1caa.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_7fface1caa.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_7fface1caa.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_8045fa92a9.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_8045fa92a9.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_8045fa92a9.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_82d5bbd21c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_82d5bbd21c.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_82d5bbd21c.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_850ca210c9.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_850ca210c9.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_850ca210c9.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_88d22eae1a.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_88d22eae1a.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_88d22eae1a.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_8e6c5242fe.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_8e6c5242fe.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_8e6c5242fe.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_916c5b7b64.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_916c5b7b64.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_916c5b7b64.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_960ae75e06.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_960ae75e06.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_960ae75e06.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_99cc46a759.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_99cc46a759.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_99cc46a759.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_9b633fa754.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_9b633fa754.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_9b633fa754.jpg
# Preprocessed and saved: augmented_dataset\prem_chopra\processed_9f2a32751d.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_0_9f2a32751d.jpg
# Augmented and saved: augmented_dataset\prem_chopra\aug_1_9f2a32751d.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0077c7c995.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0077c7c995.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0077c7c995.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0961501d1e.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0961501d1e.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0961501d1e.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0c1f1d77de.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0c1f1d77de.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0c1f1d77de.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0c47dd8063.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0c47dd8063.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0c47dd8063.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0e3f7c4e4c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0e3f7c4e4c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0e3f7c4e4c.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_0f65e50dec.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_0f65e50dec.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_0f65e50dec.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_11aeb7ece9.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_11aeb7ece9.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_11aeb7ece9.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_122067d58b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_122067d58b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_122067d58b.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_157fa10104.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_157fa10104.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_157fa10104.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_211a674ca7.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_211a674ca7.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_211a674ca7.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_221aa08e91.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_221aa08e91.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_221aa08e91.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_238a144f1e.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_238a144f1e.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_238a144f1e.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_24cf204c1c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_24cf204c1c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_24cf204c1c.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_289d961cf7.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_289d961cf7.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_289d961cf7.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_2adf0c644d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_2adf0c644d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_2adf0c644d.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_2e07f1ba31.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_2e07f1ba31.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_2e07f1ba31.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_2e47c00564.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_2e47c00564.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_2e47c00564.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_2e8a464753.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_2e8a464753.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_2e8a464753.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_2f94b7554b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_2f94b7554b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_2f94b7554b.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_32c3ba09b4.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_32c3ba09b4.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_32c3ba09b4.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_35cf7c78c1.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_35cf7c78c1.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_35cf7c78c1.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_383dc6a1ff.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_383dc6a1ff.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_383dc6a1ff.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_3b0fb3ab2d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_3b0fb3ab2d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_3b0fb3ab2d.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_3f11a1ebde.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_3f11a1ebde.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_3f11a1ebde.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_47aa9e8a1b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_47aa9e8a1b.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_47aa9e8a1b.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_5c09f298ad.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_5c09f298ad.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_5c09f298ad.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_63954faa79.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_63954faa79.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_63954faa79.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_65197a88cd.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_65197a88cd.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_65197a88cd.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_662a98df6c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_662a98df6c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_662a98df6c.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_6776e96bf5.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_6776e96bf5.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_6776e96bf5.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_67d953b242.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_67d953b242.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_67d953b242.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_6eba1d31b0.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_6eba1d31b0.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_6eba1d31b0.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_6f757e925c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_6f757e925c.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_6f757e925c.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_701b8a8bb6.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_701b8a8bb6.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_701b8a8bb6.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_7cf48072ae.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_7cf48072ae.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_7cf48072ae.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_80cf53a38d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_80cf53a38d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_80cf53a38d.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_88ceb38d92.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_88ceb38d92.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_88ceb38d92.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_8bcd45fa56.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_8bcd45fa56.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_8bcd45fa56.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_951b57660d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_951b57660d.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_951b57660d.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_9a713b9b12.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_9a713b9b12.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_9a713b9b12.jpg
# Preprocessed and saved: augmented_dataset\priyanka_chopra\processed_9cb3316730.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_0_9cb3316730.jpg
# Augmented and saved: augmented_dataset\priyanka_chopra\aug_1_9cb3316730.jpg
